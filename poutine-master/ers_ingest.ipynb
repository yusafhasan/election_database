# %% [markdown]
# ### ingest data from ers dataset ###

# %%
dataset_id = 'ers_staging'

# %%
# !bq --location=US mk --dataset {dataset_id}
# Out:
# Dataset 'alert-result-266803:ers_staging' successfully created.

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 \
--source_format=CSV {dataset_id}.Education \
'gs://bucket_mbayh_dataset2/Education.csv'
# Out:
# Waiting on bqjob_r453fad854ef25668_000001717bcad450_1 ... (2s) Current status: DONE

# %%
# !bq --location=US load --autodetect --skip_leading_rows=3 \
--source_format=CSV {dataset_id}.Population \
'gs://bucket_mbayh_dataset2/PopulationEstimates.csv'
# Out:
# Waiting on bqjob_red0e101d959beaa_000001717bcca55c_1 ... (4s) Current status: DONE

# %%
# !bq --location=US load --autodetect --skip_leading_rows=5 \
--source_format=CSV {dataset_id}.Poverty \
'gs://bucket_mbayh_dataset2/PovertyEstimates.csv'
# Out:
# Waiting on bqjob_r74b544c0507a1ad1_000001717bcda36c_1 ... (1s) Current status: DONE

# %%
# !bq --location=US load --autodetect --skip_leading_rows=5 \
--source_format=CSV {dataset_id}.Unemployment \
'gs://bucket_mbayh_dataset2/Unemployment.csv'
# Out:
# Waiting on bqjob_r174dc2ea909ed1aa_000001717bcdb06d_1 ... (1s) Current status: DONE

# %% [markdown]
# ### sample records ###

# %% [markdown]
# Education

# %%
# %%bigquery
# select * from ers_staging.Education where State = 'AL'
# limit 5
# Out:
#    FIPS_Code State          Area_name  __High_School  High_School_Only  \
# 0       1021    AL     Chilton County           5302             13125
# 1       1041    AL    Crenshaw County           2091              3753
# 2       1101    AL  Montgomery County          21646             38289
# 3       1019    AL    Cherokee County           3692              7157
# 4       1051    AL      Elmore County           7594             18304
#
#    Some_College  College  __High_School__  High_School_Only__  Some_College__  \
# 0          7147     4219             17.8                44.1            24.0
# 1          2326     1505             21.6                38.8            24.0
# 2         41976    48131             14.4                25.5            28.0
# 3          5417     2407             19.8                38.3            29.0
# 4         16197    13664             13.6                32.8            29.0
#
#    College__
# 0       14.2
# 1       15.6
# 2       32.1
# ...

# %% [markdown]
# Population

# %%
# %%bigquery
# select * from ers_staging.Population where State = 'AR'
# limit 5
# Out:
#    FIPS State         Area_Name  Rural_urban_Continuum_Code_2003  \
# 0  5133    AR     Sevier County                                7
# 1  5121    AR   Randolph County                                7
# 2  5137    AR      Stone County                                9
# 3  5025    AR  Cleveland County                                3
# 4  5039    AR     Dallas County                                6
#
#    Rural_urban_Continuum_Code_2013  Urban_Influence_Code_2003  \
# 0                                6                         11
# 1                                7                         11
# 2                                9                          9
# 3                                3                          2
# 4                                6                          6
#
#    Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 0                          6                       3            17058
# ...

# %% [markdown]
# Poverty

# %%
# %%bigquery
# select * from ers_staging.Poverty where Stabr = 'AZ'
# limit 5
# Out:
#    FIPStxt Stabr        Area_name  Rural_urban_Continuum_Code_2003  \
# 0     4000    AZ          Arizona                              NaN
# 1     4013    AZ  Maricopa County                              1.0
# 2     4021    AZ     Pinal County                              1.0
# 3     4019    AZ      Pima County                              2.0
# 4     4005    AZ  Coconino County                              3.0
#
#    Urban_Influence_Code_2003  Rural_urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        1.0                              1.0
# 2                        1.0                              1.0
# 3                        2.0                              2.0
# 4                        2.0                              3.0
#
#    Urban_Influence_Code_2013  POVALL_2018  CI90LBAll_2018  CI90UBALL_2018  \
# 0                        NaN       990291          970614         1009968
# ...

# %% [markdown]
# Unemployment

# %%
# %%bigquery
# select * from ers_staging.Unemployment where State = 'CA'
# limit 5
# Out:
#    FIPS State                Area_name  Rural_urban_continuum_code_2013  \
# 0  6000    CA               California                              NaN
# 1  6001    CA       Alameda County, CA                              1.0
# 2  6013    CA  Contra Costa County, CA                              1.0
# 3  6017    CA     El Dorado County, CA                              1.0
# 4  6037    CA   Los Angeles County, CA                              1.0
#
#    Urban_influence_code_2013  Metro_2013  _Civilian_labor_force_2007_  \
# 0                        NaN         NaN                     17893080
# 1                        1.0         1.0                       745198
# 2                        1.0         1.0                       514317
# 3                        1.0         1.0                        90382
# 4                        1.0         1.0                      4864160
#
#    _Employed_2007_  _Unemployed_2007_  Unemployment_rate_2007  ...  \
# ...
